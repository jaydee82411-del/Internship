# %%
print("hello world")
# Out:
# hello world

# %%
import numpy as np
arr = np.array([1, 2, 3, 4])
print(arr)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import numpy as np
#       2 arr = np.array([1, 2, 3, 4])
#       3 print(arr)
#
# ModuleNotFoundError: No module named 'numpy'

# %%
pip install numpy
# Out:
# ...
#    ---------------------------------------- 0.0/12.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.4 MB ? eta -:--:--
#     --------------------------------------- 0.3/12.4 MB ? eta -:--:--
#     --------------------------------------- 0.3/12.4 MB ? eta -:--:--
#    - -------------------------------------- 0.5/12.4 MB 808.0 kB/s eta 0:00:15
#    -- ------------------------------------- 0.8/12.4 MB 962.4 kB/s eta 0:00:13
#    -- ------------------------------------- 0.8/12.4 MB 962.4 kB/s eta 0:00:13
#    --- ------------------------------------ 1.0/12.4 MB 805.6 kB/s eta 0:00:15
#    ---- ----------------------------------- 1.3/12.4 MB 904.9 kB/s eta 0:00:13
#    ----- ---------------------------------- 1.6/12.4 MB 979.1 kB/s eta 0:00:12
#    ----- ---------------------------------- 1.6/12.4 MB 979.1 kB/s eta 0:00:12
# ...

# %%
import numpy as np
array = np.array([1, 2, 3, 4)]
print(arr)
# Out:
#   Cell In[4], line 2
#     array = np.array([1, 2, 3, 4)]
#                                 ^
# SyntaxError: closing parenthesis ')' does not match opening parenthesis '['

# %%
import numpy as np
array = np.array([1, 2, 3, 4])
print(arr)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 3
#       1 import numpy as np
#       2 array = np.array([1, 2, 3, 4])
# ----> 3 print(arr)
#
# NameError: name 'arr' is not defined

# %%
import numpy as np
array = np.array([1, 2, 3, 4])
print(array)
# Out:
# [1 2 3 4]

# %%
#we created the array in the previous cell#
#now we do indexing, it helps in accessing items with the first item being 0#
print(array[0])
# Out:
# 1

# %%
print(array[2])
# Out:
# 3

# %%
#SLICING, which helps us get a range of values#
print(array[1:3])
# Out:
# [2 3]

# %%
print(array[2:3])
# Out:
# [3]

# %%
#Mathematical Operations, now we do simple maths operation#
array2 = np.array([20, 3, 23, 45])
print(array2)
# Out:
# [20  3 23 45]

# %%
arra3 = array + array2
print(arra3)
# Out:
# [21  5 26 49]

# %%
print(arra3 * array2)
# Out:
# [ 420   15  598 2205]
