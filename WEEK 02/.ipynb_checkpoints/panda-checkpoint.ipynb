# %%
import pandas as pd

data = {
    "name": ["jay", "david", "adedoyin"],
    "Age": [221, 12, 21]
}

dataframe = pd.DataFrame(data)
print(dataframe)
# Out:
#        name  Age
# 0       jay  221
# 1     david   12
# 2  adedoyin   21

# %%
impport pandas as pd

data = {
    "name": ["jay", "david", "adedoyin"],
    "Age": [221, 12, 21]
}

dataframe = pd.Dataframe(data)
print(dataframe)

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
data = {
    "Name": ["jay", "david", "abiodun"],
    "Age": [21, 223, 33]
}

dataframe = pd.DataFrame(data)
print(dataframe)
# Out:
#       Name  Age
# 0      jay   21
# 1    david  223
# 2  abiodun   33

# %%
ages = pd.Series([21, 223, 33])
print(ages)
# Out:
# 0     21
# 1    223
# 2     33
# dtype: int64

# %%
import pandas as pd

# %%
ages = pd.Series([21, 223, 33])
print(ages)
# Out:
# 0     21
# 1    223
# 2     33
# dtype: int64

# %%
dataframe.to_csv("students.csv", index=False)
print(dataframe)
# Out:
#       Name  Age
# 0      jay   21
# 1    david  223
# 2  abiodun   33

# %%
new_dataframe = pd.read_csv("students.csv")
print(new_dataframe)
# Out:
#       Name  Age
# 0      jay   21
# 1    david  223
# 2  abiodun   33

# %% [raw]
# print(dataframe[dataframe["age"] > 12])

# %%
print(dataframe[dataframe["Age"]>12])
# Out:
#       Name  Age
# 0      jay   21
# 1    david  223
# 2  abiodun   33

# %%
print(dataframe[dataframe["Age"]>200])
# Out:
#     Name  Age
# 1  david  223

# %%
print(dataframe[dataframe["Age"]<1])
# Out:
# Empty DataFrame
# Columns: [Name, Age]
# Index: []

# %%
print(dataframe["Age"].mean())
# Out:
# 92.33333333333333

# %%
print(dataframe["Age"].mode())
# Out:
# 0     21
# 1     33
# 2    223
# Name: Age, dtype: int64

# %%
print(dataframe["Age"].median())
# Out:
# 33.0

# %%
print(dataframe["Age"].sum())
# Out:
# 277

# %%
print(dataframe["Age"].max())
# Out:
# 223

# %%
print(dataframe["Age"].min())
# Out:
# 21
