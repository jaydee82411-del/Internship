# %%
#importing libraries
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras import layers, models
from tensorflow.keras.applications import MobileNetV2
import tensorflow_datasets as tfds
# Out:
# ERROR:absl:Detected incompatible Protobuf Gencode/Runtime versions when loading tensorflow_metadata/proto/v0/anomalies.proto: gencode 6.31.1 runtime 5.29.6. Runtime version cannot be older than the linked gencode version. See Protobuf version guarantees at https://protobuf.dev/support/cross-version-runtime-guarantee.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/tensorflow_datasets/__init__.py", line 79, in <module>
#     from tensorflow_datasets import rlds  # pylint: disable=g-bad-import-order
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/tensorflow_datasets/rlds/__init__.py", line 21, in <module>
#     from tensorflow_datasets.rlds import envlogger_reader
#   File "/usr/local/lib/python3.12/dist-packages/tensorflow_datasets/rlds/envlogger_reader.py", line 21, in <module>
#     from tensorflow_datasets.core.utils.lazy_imports_utils import tree
# ...

# %%
#now we'll liad the pre trained model
base_model = MobileNetV2(
    weights="imagenet",
    include_top=False,
    input_shape=(224, 224, 3)
)

# %%
#now feature extraction
base_model.trainable = False
#now we creating our model
model = models.Sequential([
    base_model,
    layers.GlobalAveragePooling2D(),
    layers.Dense(128, activation="relu"),
    layers.Dense(1, activation="sigmoid")
])

# %%
#compiling the model
model.compile(
    optimizer="adam",
    loss="binary_crossentropy",
    metrics=["accuracy"]
)

# %%
#before training the training the model, ill first load the dataset(cats and dogs)
dataset_url = "https://storage.googleapis.com/mledu-datasets/cats_and_dogs_filtered.zip"
zip_dir = tf.keras.utils.get_file("cats_and_dogs_filtered.zip", origin=dataset_url, extract=True)
base_dir = zip_dir.replace(".zip", "")
train_dir = base_dir + "/train"
validation_dir = base_dir + "/validation"
# Out:
# ...
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/keras/src/utils/file_utils.py in get_file(fname, origin, untar, md5_hash, file_hash, cache_subdir, hash_algorithm, extract, archive_format, cache_dir, force_download)
#     353             try:
# --> 354                 urlretrieve(origin, download_target, DLProgbar())
#     355             except urllib.error.HTTPError as e:
#
# /usr/lib/python3.12/urllib/request.py in urlretrieve(url, filename, reporthook, data)
#     239
# --> 240     with contextlib.closing(urlopen(url, data)) as fp:
#     241         headers = fp.info()
#
# /usr/lib/python3.12/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     214         opener = _opener
# --> 215     return opener.open(url, data, timeout)
#     216
#
# ...

# %%
#training the model
history = model.fit(
    train_data,
    validation_data=val_data,
    epochs=5
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2539/2812289403.py in <cell line: 0>()
#       1 #training the model
#       2 history = model.fit(
# ----> 3     train_data,
#       4     validation_data=val_data,
#       5     epochs=5
#
# NameError: name 'train_data' is not defined
